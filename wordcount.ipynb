# %%
from pyspark import SparkConf,SparkContext
import collections

# %%
input=sc.textFile("file:///home/admin/Frank-Kanes/book.txt")

# %%
words=input.flatMap(lambda x: x.split())

# %%
wordcounts=words.countByValue()

# %%
for word,count in wordcounts.items():
    cleanword=word.encode('ascii','ignore')
    if(cleanword):
        print(cleanword.decode() + " " + str(count))
# Out:
# considered. 1
# considered? 1
# Does 2
# ocean, 1
# Dartmouth, 1
# hanging 1
# payoff 2
# increase 9
# entirely 1
# LAST 1
# Discarding 1
# oceans 1
# advice. 1
# advice, 7
# ever-improving 1
# writing, 1
# basics 2
# job), 1
# TELLING 1
# AdSense, 1
# non-compete 2
# Conventional 1
# 27, 1
# second 3
# sales? 1
# Kane, 2
# Kane. 1
# (Obamacare,) 1
# sales. 6
# sales, 9
# high-dollar 1
# designing 2
# "moderately 1
# evaluating 2
# resignation. 1
# leaning 2
# here 11
# careers. 1
# Rumsey, 1
# affiliated 1
# Insider11. 1
# reasons: 1
# separation 1
# kids 5
# reports 2
# Choosing 1
# NOT 2
# military 2
# interesting? 1
# criticism 1
# Three 2
# replace 4
# brought 1
# remnant 1
# anywhere. 1
# stern 1
# "The 4
# cheating 1
# revenue, 2
# concept! 1
# revenue. 4
# catchy 1
# revenue! 1
# therefore 2
# strike 1
# until 15
# ability. 1
# paperwork 2
# relax 2
# successful 14
# brings 3
# tying 1
# hold 1
# circumstances 1
# pursue 1
# liability, 1
# placements. 1
# marketer, 1
# ...

# %% [markdown]
# # wordcountBetter

# %%
import re

# %%
def normalizewords(text):
    return re.compile(r'\W+',re.UNICODE).split(text.lower())

# %%
words=input.flatMap(normalizewords)

# %%
wordcounts=words.countByValue()

# %%
for word,count in wordcounts.items():
    cleanword=word.encode('ascii','ignore')
    if(cleanword):
        print(cleanword.decode() + " " + str(count))
# Out:
# limited 12
# transitions 1
# similarity 1
# hats 1
# child 1
# desirable 1
# chaos 2
# four 1
# immersive 1
# sleep 5
# preface 2
# ridiculous 1
# saved 6
# payoff 2
# relationships 1
# looking 13
# violate 1
# crises 1
# disability 2
# extrapolate 1
# swat 1
# under 8
# worth 39
# saves 1
# risk 18
# unsold 1
# blanket 2
# oceans 4
# handling 2
# every 32
# updates 3
# kick 1
# affect 9
# adaptive 1
# vast 2
# school 3
# basics 12
# frankly 1
# skills 17
# fondly 1
# companies 31
# unrelated 1
# math 3
# shows 3
# straight 2
# whirlwind 1
# enjoy 13
# force 1
# disciplines 2
# consistent 1
# hanging 2
# estimates 3
# direct 13
# complement 1
# budget 12
# surrounding 3
# electricians 1
# street 2
# iraq 2
# estimated 2
# even 104
# established 2
# errors 1
# decisions 5
# selected 1
# near 5
# asia 1
# bonuses 2
# above 5
# designing 4
# new 153
# net 13
# conjure 1
# ever 10
# told 6
# specialist 1
# niche 20
# evaluating 4
# mailings 1
# never 27
# disposable 1
# here 29
# ...

# %% [markdown]
# # Implement countbyValue() the hard way to create new RDD

# %%
wordCounts=words.map(lambda x: (x,1)).reduceByKey(lambda x,y: (x+y))

# %%
wordCountSorted=wordCounts.map(lambda x: (x[1] , x[0])).sortByKey()

# %%
results=wordCountSorted.collect()
results
# Out:
# [(1, u'hats'),
#  (1, u'desirable'),
#  (1, u'four'),
#  (1, u'relationships'),
#  (1, u'extrapolate'),
#  (1, u'adaptive'),
#  (1, u'fondly'),
#  (1, u'announced'),
#  (1, u'force'),
#  (1, u'consistent'),
#  (1, u'electricians'),
#  (1, u'asia'),
#  (1, u'mailings'),
#  (1, u'disposable'),
#  (1, u'104'),
#  (1, u'obtained'),
#  (1, u'forum'),
#  (1, u'harass'),
#  (1, u'calculations'),
#  (1, u'astute'),
#  (1, u'criticism'),
#  (1, u'psychological'),
#  (1, u'conflicts'),
#  (1, u'achievable'),
#  (1, u'counts'),
#  (1, u'landscape'),
#  (1, u'catchy'),
#  (1, u'hospital'),
#  (1, u'strike'),
#  (1, u'breathe'),
#  (1, u'award'),
#  (1, u'93'),
#  (1, u'outdated'),
#  (1, u'divorced'),
#  (1, u'pursue'),
#  (1, u'roof'),
#  (1, u'exceptions'),
#  (1, u'addictive'),
#  (1, u'household'),
#  (1, u'appointment'),
#  (1, u'machine'),
#  (1, u'hot'),
#  (1, u'fudge'),
#  (1, u'mouths'),
#  (1, u'curiosity'),
#  (1, u'chump'),
#  (1, u'types'),
#  (1, u'attempt'),
#  (1, u'attracts'),
# ...

# %%
for count,word in results:
    cleanword=word.encode('ascii','ignore')
    if(cleanword):
        print(cleanword.decode() + ":" + str(count))
# Out:
# hats:1
# desirable:1
# four:1
# relationships:1
# extrapolate:1
# adaptive:1
# fondly:1
# announced:1
# force:1
# consistent:1
# electricians:1
# asia:1
# mailings:1
# disposable:1
# 104:1
# obtained:1
# forum:1
# harass:1
# calculations:1
# astute:1
# criticism:1
# psychological:1
# conflicts:1
# achievable:1
# counts:1
# landscape:1
# catchy:1
# hospital:1
# strike:1
# breathe:1
# award:1
# 93:1
# outdated:1
# divorced:1
# pursue:1
# roof:1
# exceptions:1
# addictive:1
# household:1
# appointment:1
# machine:1
# hot:1
# fudge:1
# mouths:1
# curiosity:1
# chump:1
# types:1
# attempt:1
# attracts:1
# teammates:1
# goodbye:1
# realizing:1
# salon:1
# rewarded:1
# digest:1
# edits:1
# 401:1
# weeks:1
# versus:1
# affected:1
# prevented:1
# unemployed:1
# reaches:1
# niches:1
# reasonably:1
# legwork:1
# substantially:1
# reminding:1
# fiji:1
# braces:1
# newly:1
# independence:1
# substantiation:1
# competes:1
# onto:1
# iag:1
# characters:1
# coding:1
# spinning:1
# traction:1
# ...

# %%
wordCountSorted1=wordCounts.sortByKey()

# %%
results1=wordCountSorted1.collect()
results1
# Out:
# [(u'', 772),
#  (u'0', 1),
#  (u'000', 24),
#  (u'05', 1),
#  (u'07', 1),
#  (u'1', 13),
#  (u'10', 23),
#  (u'100', 10),
#  (u'1000', 1),
#  (u'101', 2),
#  (u'104', 1),
#  (u'1099', 1),
#  (u'11', 3),
#  (u'1124', 1),
#  (u'12', 1),
#  (u'125', 1),
#  (u'13', 1),
#  (u'14', 1),
#  (u'15', 1),
#  (u'150', 1),
#  (u'17', 1),
#  (u'18', 1),
#  (u'19', 1),
#  (u'2', 5),
#  (u'20', 5),
#  (u'2006', 1),
#  (u'20081', 1),
#  (u'2009', 1),
#  (u'2010', 3),
#  (u'2011', 4),
#  (u'2012', 8),
#  (u'2013', 2),
#  (u'2014', 8),
#  (u'2015', 4),
#  (u'212', 1),
#  (u'22', 3),
#  (u'27', 3),
#  (u'28', 1),
#  (u'29', 2),
#  (u'3', 13),
#  (u'300', 5),
#  (u'312', 1),
#  (u'360', 1),
#  (u'3d', 2),
#  (u'4', 9),
#  (u'40', 4),
#  (u'401', 1),
#  (u'41', 2),
#  (u'43', 1),
#  (u'46', 3),
#  (u'47', 1),
#  (u'49', 1),
#  (u'5', 13),
#  (u'50', 16),
#  (u'500', 1),
#  (u'55', 2),
#  (u'6', 5),
#  (u'60', 1),
#  (u'62', 3),
#  (u'65', 1),
#  (u'68', 1),
#  (u'7', 5),
#  (u'70', 1),
#  (u'75', 2),
# ...

# %%
for word,count in results1:
    cleanword=word.encode('ascii','ignore')
    if(cleanword):
        print(cleanword.decode() + ":" + str(count))
# Out:
# 0:1
# 000:24
# 05:1
# 07:1
# 1:13
# 10:23
# 100:10
# 1000:1
# 101:2
# 104:1
# 1099:1
# 11:3
# 1124:1
# 12:1
# 125:1
# 13:1
# 14:1
# 15:1
# 150:1
# 17:1
# 18:1
# 19:1
# 2:5
# 20:5
# 2006:1
# 20081:1
# 2009:1
# 2010:3
# 2011:4
# 2012:8
# 2013:2
# 2014:8
# 2015:4
# 212:1
# 22:3
# 27:3
# 28:1
# 29:2
# 3:13
# 300:5
# 312:1
# 360:1
# 3d:2
# 4:9
# 40:4
# 401:1
# 41:2
# 43:1
# 46:3
# 47:1
# 49:1
# 5:13
# 50:16
# 500:1
# 55:2
# 6:5
# 60:1
# 62:3
# 65:1
# 68:1
# 7:5
# 70:1
# 75:2
# 8:7
# 800:1
# 82:1
# 85:1
# 9:11
# 90:3
# 93:1
# 99:2
# ___:28
# a:1191
# aaron:3
# abandon:1
# abandoned:1
# abbreviation:1
# abilities:3
# ability:15
# able:22
# about:202
# above:5
# absolutely:1
# absorbed:1
# abstract:1
# accelerator:1
# accept:9
# accepted:3
# accepting:1
# access:4
# accident:3
# accompanied:3
# accompanies:1
# accompany:1
# accomplish:4
# accomplishing:2
# accomplishment:1
# accomplishments:1
# according:10
# accordingly:3
# account:30
# accountant:19
# accountants:2
# accounting:11
# ...
